# %%
#Import the necessary libraries and dependencies.
import pandas as pd
from pathlib import Path

# %%
#Read in the loans.csv data.
csvpath = Path("loans.csv")
loans = pd.read_csv(csvpath)

# %%
#Show the first 10 records of the data.
loans.head(10)
# Out:
#    loan_amnt  funded_amnt  funded_amnt_inv       term  int_rate  installment  \
# 0      10000        10000          10000.0  36 months    0.1033       324.23
# 1       4000         4000           4000.0  36 months    0.2340       155.68
# 2       5000         5000           5000.0  36 months    0.1797       180.69
# 3       9600         9600           9600.0  36 months    0.1298       323.37
# 4       2500         2500           2500.0  36 months    0.1356        84.92
# 5      30000        30000          30000.0  60 months    0.1894       777.23
# 6      23000        23000          23000.0  60 months    0.2089       620.81
# 7      32075        32075          32075.0  60 months    0.1180       710.26
# 8       8000         8000           8000.0  36 months    0.2340       311.35
# 9      10000        10000          10000.0  60 months    0.1992       264.50
#
#   grade sub_grade           emp_title emp_length home_ownership  annual_inc  \
# ...

# %%
#View summary statistics for the loans.csv data.
#loans.shape()
loans.describe()
# Out:
#            loan_amnt    funded_amnt  funded_amnt_inv       int_rate  \
# count  128412.000000  128412.000000    128412.000000  128412.000000
# mean    15971.321021   15971.321021     15968.498166       0.129302
# std     10150.384233   10150.384233     10152.168970       0.050904
# min      1000.000000    1000.000000       725.000000       0.060000
# 25%      8000.000000    8000.000000      8000.000000       0.084600
# 50%     14000.000000   14000.000000     14000.000000       0.118000
# 75%     21600.000000   21600.000000     21600.000000       0.161400
# max     40000.000000   40000.000000     40000.000000       0.309900
#
#          installment    annual_inc
# count  128412.000000  1.284120e+05
# mean      463.259353  8.279733e+04
# std       285.718256  1.082985e+05
# min        30.480000  0.000000e+00
# 25%       253.630000  4.705800e+04
# 50%       382.905000  6.800000e+04
# 75%       622.680000  9.900000e+04
# max      1618.240000  9.757200e+06

# %%
#Create a subset DataFrame filtered_df by filtering out the important columns:
#loan_amnt
#term
#int_rate
#emp_title
#annual_inc
#purpose

# use iloc and grab columns 0, 3, 4, 8, 11, -1
filtered_df = loans.iloc[:, [0, 3, 4, 8, 11, -1]]
filtered_df.head()
# Out:
#    loan_amnt       term  int_rate       emp_title  annual_inc  \
# 0      10000  36 months    0.1033             NaN    280000.0
# 1       4000  36 months    0.2340        Security     90000.0
# 2       5000  36 months    0.1797  Administrative     59280.0
# 3       9600  36 months    0.1298             NaN     35704.0
# 4       2500  36 months    0.1356            Chef     55000.0
#
#               purpose
# 0  debt_consolidation
# 1  debt_consolidation
# 2  debt_consolidation
# 3    home_improvement
# 4  debt_consolidation

# %%
#Filter filtered_df by row values where term is equal to 36 months in order to focus on only three-year loan records.
term_df = filtered_df.loc[filtered_df["term"] == "36 months"].copy()
term_df.describe()
# Out:
#           loan_amnt      int_rate    annual_inc
# count  88179.000000  88179.000000  8.817900e+04
# mean   13279.580456      0.120610  8.043616e+04
# std     9479.610905      0.048955  1.109251e+05
# min     1000.000000      0.060000  0.000000e+00
# 25%     6000.000000      0.078400  4.500000e+04
# 50%    10000.000000      0.110600  6.500000e+04
# 75%    18000.000000      0.150200  9.500000e+04
# max    40000.000000      0.309900  9.000000e+06

# %%
# Change row values within the 'term' column from '36 months' to '3 Years'
term_df.loc[term_df["term"] == "36 months", "term"] = "3 years"
term_df.head()
# Out:
#    loan_amnt     term  int_rate       emp_title  annual_inc  \
# 0      10000  3 years    0.1033             NaN    280000.0
# 1       4000  3 years    0.2340        Security     90000.0
# 2       5000  3 years    0.1797  Administrative     59280.0
# 3       9600  3 years    0.1298             NaN     35704.0
# 4       2500  3 years    0.1356            Chef     55000.0
#
#               purpose
# 0  debt_consolidation
# 1  debt_consolidation
# 2  debt_consolidation
# 3    home_improvement
# 4  debt_consolidation

# %%
# Change row values within the 'emp_title' column from NaN to 'Unknown'
term_df.loc[term_df["emp_title"].isnull(), "emp_title"] = "unknown"
term_df.head()
# Out:
#    loan_amnt     term  int_rate       emp_title  annual_inc  \
# 0      10000  3 years    0.1033         unknown    280000.0
# 1       4000  3 years    0.2340        Security     90000.0
# 2       5000  3 years    0.1797  Administrative     59280.0
# 3       9600  3 years    0.1298         unknown     35704.0
# 4       2500  3 years    0.1356            Chef     55000.0
#
#               purpose
# 0  debt_consolidation
# 1  debt_consolidation
# 2  debt_consolidation
# 3    home_improvement
# 4  debt_consolidation

# %%
# Describe summary statistics for three-year loans
term_df.describe(include="all")
# Out:
#            loan_amnt     term      int_rate emp_title    annual_inc  \
# count   88179.000000    88179  88179.000000     88179  8.817900e+04
# unique           NaN        1           NaN     31470           NaN
# top              NaN  3 years           NaN   unknown           NaN
# freq             NaN    88179           NaN     15669           NaN
# mean    13279.580456      NaN      0.120610       NaN  8.043616e+04
# std      9479.610905      NaN      0.048955       NaN  1.109251e+05
# min      1000.000000      NaN      0.060000       NaN  0.000000e+00
# 25%      6000.000000      NaN      0.078400       NaN  4.500000e+04
# 50%     10000.000000      NaN      0.110600       NaN  6.500000e+04
# 75%     18000.000000      NaN      0.150200       NaN  9.500000e+04
# max     40000.000000      NaN      0.309900       NaN  9.000000e+06
#
#                    purpose
# count                88179
# unique                  12
# top     debt_consolidation
# freq                 45456
# ...

# %%
# Calculate unique values and counts for employee titles of 3 year customer loans
term_df['emp_title'].value_counts()
# Out:
# unknown                       15669
# Teacher                        1433
# Manager                        1207
# Registered Nurse                672
# Driver                          654
#                               ...
# mgt dept. embroider               1
# Financial Services Officer        1
# Office Manager/Controller         1
# Motorcoach Operator               1
# Key Accounts Manager              1
# Name: emp_title, Length: 31470, dtype: int64

# %%
# Show Unique Values for Purpose of 3 Year Loans
# Calculate unique values and counts for loan purposes of 3 year customer loans
term_df["purpose"].value_counts()
# Out:
# debt_consolidation    45456
# credit_card           24780
# other                  5836
# home_improvement       5446
# major_purchase         1795
# medical                1245
# car                     838
# small_business          828
# vacation                749
# house                   596
# moving                  547
# renewable_energy         63
# Name: purpose, dtype: int64

# %%
#Show Summary Statistics for 3 Year Loans of Customers with Annual Income Greater Than $80,000
# Display summary statistics where annual income is greater than $80,000 to find count and mean
term_df.loc[term_df["annual_inc"] > 80000].describe()
# Out:
#           loan_amnt      int_rate    annual_inc
# count  29748.000000  29748.000000  2.974800e+04
# mean   18240.116142      0.114116  1.389634e+05
# std    10991.909117      0.048067  1.752361e+05
# min     1000.000000      0.060000  8.000100e+04
# 25%    10000.000000      0.075600  9.500000e+04
# 50%    15700.000000      0.104700  1.120000e+05
# 75%    25000.000000      0.144700  1.500000e+05
# max    40000.000000      0.309400  9.000000e+06

# %%
#Show Summary Statistics for 3 Year Loans of Customers with Annual Income Less Than $80,000
# Display summary statistics where annual income is less than $80,000 to find count and mea
term_df.loc[term_df['annual_inc'] < 80000].describe()
# Out:
#           loan_amnt      int_rate    annual_inc
# count  56015.000000  56015.000000  56015.000000
# mean   10607.487727      0.124268  49372.805964
# std     7318.791900      0.049137  16669.098821
# min     1000.000000      0.060000      0.000000
# 25%     5000.000000      0.081900  37000.000000
# 50%     9600.000000      0.113100  50000.000000
# 75%    14000.000000      0.150200  62635.500000
# max    40000.000000      0.309900  79999.000000

# %%
# What insights can we answer regarding 3 year loans?
# What kind of customers (employee title) seem to ask for three-year loans most frequently?
# What are three-year loans generally used for?
# What is the difference in count of three-year loan customers with annual incomes greater than 80,000 
#compared to those with annual incomes less than 80,000?
# What is the difference in interest rates of three-year loan customers with annual incomes greater than 80,000 
#compared to those with annual incomes less than 80,000?
# Interestingly enough Teachers and Managers seem to be the top two contenders for requesting three-year loans. 
#In addition, there are a disproporionate amount of 'Unknown' or un-reported employee titles. Unless this field is optional, 
#this could signal a potential data quality problem.

#Answers
# From the value counts of loan purposes, it looks like three-year loans are generally used to consolidate debt.

# A majority of three-year loan customers have annual incomes of less than 80,000. Counts of customers with 
#annual incomes less than 80,000 compared to greater than 80,000 stand at 56,015 customers vs 29,748 customers, respectively.

# Interest rates between customers with annual incomes greater than 80,000 compared to those with less than 80,000 
#differ by approximately 1%; Interest rates were 12.43% and 12.41%, respectively.
