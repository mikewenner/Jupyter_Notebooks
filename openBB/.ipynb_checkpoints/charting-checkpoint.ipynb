# %%
from openbb_terminal.sdk import openbb

# %matplotlib inline

# %%
# Look at a plot of SPY monthly

spy_monthly = openbb.stocks.load(
        symbol = 'SPY',
        start_date = '1993-11-01',
        monthly = True)
spy_monthly.head()
# Out:
# Loading Monthly data for SPY with starting period 1993-11-01.
#                 Open      High       Low     Close  Adj Close    Volume
# date
# 1993-11-01  46.78125  47.00000  45.53125  46.34375  27.082022   5351100
# 1993-12-01  46.59375  47.15625  46.37500  46.59375  27.228117   6128000
# 1994-01-01  46.59375  48.31250  46.40625  48.21875  28.370615   6837100
# 1994-02-01  48.15625  48.28125  46.56250  46.81250  27.543230  10974400
# 1994-03-01  46.81250  47.31250  43.53125  44.59375  26.237766  14705500

# %%
# Now plot using a candle chart
openbb.stocks.candle(
    data = spy_monthly,
    asset_type = 'SPY - Monthly Chart from November, 1993',
    symbol = ''
)

# %%
#Quick Daily chart for the past 3 years

openbb.stocks.candle("SPY")
# Out:
# Loading Daily data for SPY with starting period 2020-01-21.

# %%
# look at 15min chart

openbb.stocks.candle("QQQ", interval=15)
# Out:
# Loading Intraday 15min data for QQQ with starting period 2022-11-26.

# %%
#Looking at vwap
spy_vwap = openbb.ta.vwap(data = openbb.stocks.load('SPY', interval = 15))
spy_vwap
# Out:
# Loading Intraday 15min data for SPY with starting period 2022-11-24.
#                          VWAP_D
# date
# 2022-11-25 09:30:00  401.924998
# 2022-11-25 09:45:00  402.036756
# 2022-11-25 10:00:00  402.147466
# 2022-11-25 10:15:00  402.298709
# 2022-11-25 10:30:00  402.333523
# ...                         ...
# 2023-01-20 15:00:00  391.744416
# 2023-01-20 15:15:00  391.911501
# 2023-01-20 15:30:00  392.063867
# 2023-01-20 15:45:00  392.544463
# 2023-01-20 16:00:00  392.544463
#
# [966 rows x 1 columns]

# %%
# Putting VWAP on a 15min chart
openbb.ta.vwap_chart(
    data = openbb.stocks.load('SPY', interval = 15))
# Out:
# Loading Intraday 15min data for SPY with starting period 2022-11-24.
# No start date specified. Start date: 2022-11-25
# No end date specified. End date: 2023-01-20

# %%
openbb.ta.bbands(
    data = openbb.stocks.load('SPY', interval = 15), window = 15, n_std = 2, mamode = "ema")
# Out:
# Loading Intraday 15min data for SPY with starting period 2022-11-24.
#                      BBL_15_2.0  BBM_15_2.0  BBU_15_2.0  BBB_15_2.0  \
# date
# 2022-11-25 13:00:00  402.027208  402.376941  402.726673    0.173833
# 2022-11-28 09:30:00  401.018019  402.114823  403.211627    0.545518
# 2022-11-28 09:45:00  400.219045  401.833857  403.448670    0.803721
# 2022-11-28 10:00:00  399.737185  401.615875  403.494564    0.935565
# 2022-11-28 10:15:00  399.086921  401.332641  403.578361    1.119132
# ...                         ...         ...         ...         ...
# 2023-01-20 15:00:00  390.763427  393.078776  395.394126    1.178059
# 2023-01-20 15:15:00  390.831048  393.341428  395.851809    1.276438
# 2023-01-20 15:30:00  390.970946  393.553125  396.135304    1.312239
# 2023-01-20 15:45:00  391.072874  393.838984  396.605094    1.404691
# 2023-01-20 16:00:00  391.224256  394.094112  396.963967    1.456431
#
#                      BBP_15_2.0
# date
# 2022-11-25 13:00:00    0.404293
# 2022-11-28 09:30:00   -0.336441
# 2022-11-28 09:45:00   -0.108975
# 2022-11-28 10:00:00    0.093898
# 2022-11-28 10:15:00    0.058575
# ...                         ...
# 2023-01-20 15:00:00    1.014224
# 2023-01-20 15:15:00    0.866192
# 2023-01-20 15:30:00    0.786943
# 2023-01-20 15:45:00    0.861702
# 2023-01-20 16:00:00    0.811147
#
# [952 rows x 5 columns]

# %%
openbb.ta.bbands_chart(
    data = openbb.stocks.load('SPY', interval = 15), window = 15, n_std = 2, mamode = "ema")
# Out:
# Loading Intraday 15min data for SPY with starting period 2022-11-24.

# %%
# plotting a futures curve chart
openbb.futures.curve_chart("CL")
