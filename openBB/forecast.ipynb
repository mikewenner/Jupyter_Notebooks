# %%
from openbb_terminal.sdk import openbb
import pandas as pd

# %matplotlib inline

# %%
spy = openbb.stocks.load("SPY", start_date = "2015-01-01")
spy.head()
# Out:
# Loading Daily data for SPY with starting period 2015-01-02.
#                   Open        High         Low       Close   Adj Close  \
# date
# 2015-01-02  206.380005  206.880005  204.179993  205.429993  177.463623
# 2015-01-05  204.169998  204.369995  201.350006  201.720001  174.258652
# 2015-01-06  202.089996  202.720001  198.860001  199.820007  172.617355
# 2015-01-07  201.419998  202.720001  200.880005  202.309998  174.768372
# 2015-01-08  204.009995  206.160004  203.990005  205.899994  177.869644
#
#                Volume
# date
# 2015-01-02  121465900
# 2015-01-05  169632600
# 2015-01-06  209151400
# 2015-01-07  125346700
# 2015-01-08  147217800

# %%
openbb.forecast.linregr_chart(data = spy, target_column = 'Close')
# Out:
# Predicting Logistic Regression for 5 days
#   0%|          | 0/314 [00:00<?, ?it/s]
# Logistic Regression model obtains MAPE: 2.48%
#    Actual price: 410.80
# ┏━━━━━━━━━━━━┳━━━━━━━━━━━━┓
# ┃ Datetime   ┃ Prediction ┃
# ┡━━━━━━━━━━━━╇━━━━━━━━━━━━┩
# │ 2023-02-02 │ 410.66     │
# ├────────────┼────────────┤
# │ 2023-02-03 │ 411.43     │
# ├────────────┼────────────┤
# │ 2023-02-06 │ 412.00     │
# ├────────────┼────────────┤
# │ 2023-02-07 │ 411.38     │
# ├────────────┼────────────┤
# │ 2023-02-08 │ 411.95     │
# └────────────┴────────────┘
# No data for colormapping provided via 'c'. Parameters 'vmin', 'vmax' will be ignored
