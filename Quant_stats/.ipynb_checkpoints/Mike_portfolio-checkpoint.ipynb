# %%
import warnings
import pandas as pd
import numpy as np
import riskfolio as rp
from openbb_terminal.sdk import openbb
warnings.filterwarnings("ignore")
# %matplotlib inline
import seaborn as sns

# %%
pd.reset_option("display.float_format")

# %%
#Use the OpenBB SDK to pull closing price data for the past 10 years
start = '2013-02-13'
end = '2023-02-13'

symbols = ["SPY", "COST", "AVGO", "APD", "AMGN", "CVX", "AAPL", "DIS",
          "BAC", "GS", "SBUX", "COF", "ETN", "XOM", "HD", "MA",
          "QQQ", "IWM", "JNJ", "JPM", "MCD", "MRK", "MSFT", "NVDA", "NKE",
          "PEP", "PFE", "PG", "MO", "BUD", "SHW", "TSCO", "UNH", "VZ", "V", "WMT"]

data = openbb.economy.index(symbols, start_date=start, end_date=end)
data
# Out:
#                                   SPY        COST        AVGO         APD  \
# Date
# 2013-02-13 00:00:00-05:00  126.366104   83.569153   26.767319   64.430977
# 2013-02-14 00:00:00-05:00  126.482376   83.889847   27.125031   64.365646
# 2013-02-15 00:00:00-05:00  126.332901   84.013206   26.744488   64.031807
# 2013-02-19 00:00:00-05:00  127.279716   83.791176   27.048920   64.372925
# 2013-02-20 00:00:00-05:00  125.693398   83.116898   26.386776   63.581863
# ...                               ...         ...         ...         ...
# 2023-02-06 00:00:00-05:00  409.829987  515.590027  601.299988  283.029999
# 2023-02-07 00:00:00-05:00  415.190002  516.530029  614.450012  285.070007
# 2023-02-08 00:00:00-05:00  410.649994  503.809998  601.710022  287.239990
# 2023-02-09 00:00:00-05:00  407.089996  500.630005  599.409973  286.890015
# 2023-02-10 00:00:00-05:00  408.040009  499.989990  593.250000  287.820007
#
#                                  AMGN         CVX        AAPL         DIS  \
# Date
# 2013-02-13 00:00:00-05:00   65.351990   76.319016   14.405278   49.963745
# 2013-02-14 00:00:00-05:00   65.182755   76.437927   14.392322   49.891026
# 2013-02-15 00:00:00-05:00   64.328697   75.942459   14.193981   50.554653
# 2013-02-19 00:00:00-05:00   64.728783   76.576660   14.188737   50.663742
# 2013-02-20 00:00:00-05:00   65.128860   75.962303   13.845116   49.636471
# ...                               ...         ...         ...         ...
# 2023-02-06 00:00:00-05:00  241.718353  168.153488  151.498688  109.870003
# 2023-02-07 00:00:00-05:00  241.867035  172.564484  154.414230  111.629997
# 2023-02-08 00:00:00-05:00  238.100250  168.510330  151.688400  111.779999
# 2023-02-09 00:00:00-05:00  237.901993  166.964005  150.639999  110.360001
# 2023-02-10 00:00:00-05:00  240.380142  170.463074  151.009995  108.059998
#
#                                  BAC          GS  ...        PFE          PG  \
# Date                                              ...
# 2013-02-13 00:00:00-05:00  10.341105  130.554398  ...  17.901680   57.207520
# 2013-02-14 00:00:00-05:00  10.307115  131.745621  ...  17.941467   57.371914
# 2013-02-15 00:00:00-05:00  10.222143  130.951492  ...  18.093958   57.192562
# 2013-02-19 00:00:00-05:00  10.358098  134.043777  ...  18.372433   57.820232
# 2013-02-20 00:00:00-05:00  10.026706  131.111984  ...  18.279606   57.596073
# 2023-02-07 00:00:00-05:00 -0.018887  0.001334  0.003451 -0.017684  0.008194
# 2023-02-08 00:00:00-05:00 -0.012288 -0.006402  0.013295 -0.000740 -0.004842
# 2023-02-09 00:00:00-05:00 -0.016984  0.010898  0.005194 -0.017522 -0.001741
# 2023-02-10 00:00:00-05:00 -0.004406 -0.003251  0.017541  0.005024 -0.009374
#
#                                 WMT
# Date
# 2013-02-14 00:00:00-05:00 -0.007984
# 2013-02-15 00:00:00-05:00 -0.021463
# 2013-02-19 00:00:00-05:00 -0.007793
# 2013-02-20 00:00:00-05:00  0.006545
# 2013-02-21 00:00:00-05:00  0.015171
# ...                             ...
# 2023-02-06 00:00:00-05:00 -0.007268
# 2023-02-07 00:00:00-05:00  0.002133
# 2023-02-08 00:00:00-05:00 -0.005391
# 2023-02-09 00:00:00-05:00  0.009271
# 2023-02-10 00:00:00-05:00  0.015545
#
# [2516 rows x 36 columns]

# %%
# Use the `corr` function to calculate the correlation between stock returns
correlation = returns.corr()
correlation.head()
# Out:
#            SPY      COST      AVGO       APD      AMGN       CVX      AAPL  \
# SPY   1.000000  0.608160  0.668049  0.693016  0.570142  0.628123  0.719935
# COST  0.608160  1.000000  0.377855  0.414306  0.359313  0.259593  0.463021
# AVGO  0.668049  0.377855  1.000000  0.439877  0.364004  0.396397  0.565675
# APD   0.693016  0.414306  0.439877  1.000000  0.420317  0.462721  0.432988
# AMGN  0.570142  0.359313  0.364004  0.420317  1.000000  0.307524  0.370575
#
#            DIS       BAC        GS  ...       PFE        PG        MO  \
# SPY   0.673609  0.720519  0.750627  ...  0.523976  0.565727  0.479140
# COST  0.355641  0.319033  0.374683  ...  0.337557  0.482418  0.318428
# AVGO  0.416192  0.444839  0.478857  ...  0.290153  0.291972  0.259449
# APD   0.455892  0.519289  0.527112  ...  0.391120  0.445554  0.377382
# AMGN  0.330811  0.388916  0.391261  ...  0.491405  0.420546  0.301813
#
#            BUD       SHW      TSCO       UNH        VZ         V       WMT
# SPY   0.547286  0.626597  0.522275  0.629448  0.475532  0.767354  0.453606
# COST  0.261683  0.398853  0.449113  0.390949  0.357311  0.426754  0.566400
# AVGO  0.373356  0.443967  0.358696  0.388557  0.233512  0.509627  0.233887
# APD   0.414860  0.519333  0.357681  0.463860  0.367114  0.551613  0.330849
# AMGN  0.292932  0.385789  0.317919  0.463935  0.344206  0.432141  0.328033
#
# [5 rows x 36 columns]

# %%
# Use heatmap to visualize the correlation of the stocks in the portfolio
sns.heatmap(correlation, vmin=-1, vmax=1)
# Out:
# <AxesSubplot: >

# %%
#weight the portfolio (0.0285 = equal wt for 35 stocks)
#weight the portfolio
portfolio_weighted_returns = ((returns["COST"]*.0059) + (returns["AVGO"]*.0088) + (returns["APD"]*.0066) + (returns["AMGN"]*.0029) + (returns["CVX"]*.0191) + 
        (returns["AAPL"]*.0125) + (returns["DIS"]*.1366) + (returns["BAC"]*.1109) + (returns["GS"]*.0044) + (returns["SBUX"]*.0389) + 
        (returns["COF"]*.0132) + (returns["ETN"]*.0264) + (returns["XOM"]*.0345) + (returns["HD"]*.0066) + (returns["MA"]*.0125) + 
        (returns["QQQ"]*.0800) + (returns["IWM"]*.0352) + (returns["JNJ"]*.0184) + (returns["JPM"]*.0228) + (returns["MCD"]*.0330) + 
        (returns["MRK"]*.0081) + (returns["MSFT"]*.0213) + (returns["NVDA"]*.1043) + (returns["NKE"]*.0264) + (returns["PEP"]*.0110) + 
        (returns["PFE"]*.0404) + (returns["PG"]*.0125) + (returns["MO"]*.0162) + (returns["BUD"]*.0360) + (returns["SHW"]*.0073) + 
        (returns["TSCO"]*.0492) + (returns["UNH"]*.0066) + (returns["VZ"]*.0235) + (returns["V"]*.0081) + (returns["WMT"]*.0132)
        
            )
portfolio_weighted_returns.head()
# Out:
# Date
# 2013-02-14 00:00:00-05:00    0.004757
# 2013-02-15 00:00:00-05:00   -0.000332
# 2013-02-19 00:00:00-05:00    0.003672
# 2013-02-20 00:00:00-05:00   -0.014489
# 2013-02-21 00:00:00-05:00   -0.008416
# dtype: float64

# %%
#Daily returns of the portfolio
portfolio_weighted_returns.plot(
    title = "Mike Portfolio Daily Returns",
    figsize = (15, 10)
)
# Out:
# <AxesSubplot: title={'left': 'Mike Portfolio Daily Returns'}, xlabel='Date'>

# %%
#Cumulative returns of the weighted portfolio
cum_returns = (1 + portfolio_weighted_returns).cumprod()
cum_returns.plot(
    title = "Mike Portfolio Cumulative Returns",
    figsize = (15, 10),
    ylabel = "Cumulative Returns"
)
# Out:
# <AxesSubplot: title={'left': 'Mike Portfolio Cumulative Returns'}, xlabel='Date', ylabel='Cumulative Returns'>

# %%
#cumulative returns for 10k investment
initial_investment = 10000
cum_returns = (1 + portfolio_weighted_returns).cumprod()
(initial_investment * cum_returns).plot(
    title = "Mike Portfolio 10k Basis",
    figsize = (15, 10)
)
# Out:
# <AxesSubplot: title={'left': 'Mike Portfolio 10k Basis'}, xlabel='Date'>

# %%
#Pull out the spy and look at its returns as a comparison
spy_returns = returns["SPY"]
spy_cum_returns = (1 + spy_returns).cumprod()

ax = cum_returns.plot(figsize = (15,10))
spy_cum_returns.plot(ax=ax)
ax.legend(["Mike Portfolio Cumulative Returns", "SPY Cumulative Returns"])

# %%
#Look at distribution & Outliers of the returns of the weighted portfolio vs SPY
box_plot_returns = pd.concat([portfolio_weighted_returns, spy_returns], axis="columns", join = "inner")

box_plot_returns.plot(
    kind = "box",
    figsize = (15,8),
    title = "Returns Comparison of Portfolio vs SPY"

)
# Out:
# <AxesSubplot: title={'left': 'Returns Comparison of Portfolio vs SPY'}>

# %%
# Summary stats of portfolio vs SPY

portfolio_summary_stats = openbb.qa.summary(portfolio_weighted_returns)
spy_summary_stats = openbb.qa.summary(spy_returns)
summary_stats = pd.concat([portfolio_summary_stats, spy_summary_stats], axis="columns", join = "inner")
summary_stats
# Out:
#                  0          SPY
# count  2516.000000  2516.000000
# mean      0.000768     0.000527
# std       0.012254     0.010989
# min      -0.127426    -0.109424
# 10%      -0.011740    -0.010631
# 25%      -0.003992    -0.003642
# 50%       0.000907     0.000643
# 75%       0.006281     0.005608
# 90%       0.012817     0.011564
# max       0.121415     0.090603
# var       0.000150     0.000121

# %%
sharpe_ratio_df = pd.concat([portfolio_weighted_returns, returns], axis="columns", join = "inner")
sharpe_ratios.sort_values(ascending = False, inplace=True)
sharpe_ratios.plot(
    kind = "bar",
    title = "Sharpe Ratio Analysis (0=weighted portfolio)",
    figsize=(15,8),
    color=["yellow", "yellow", "yellow", "yellow","green","yellow", "yellow", "yellow", "yellow",
          "yellow", "yellow", "green", "yellow","yellow", "yellow", "yellow", "yellow", "yellow", "yellow", "yellow", "yellow", "yellow", "yellow",
          "yellow", "yellow", "yellow", "yellow", "yellow", "yellow","yellow", "yellow", "yellow", "yellow"]



)
# Out:
# <AxesSubplot: title={'left': 'Sharpe Ratio Analysis (0=weighted portfolio)'}>

# %%
#Get an overview of the stocks in the portfolio sorted by market cap
mike_portfolio_overview = openbb.stocks.ca.screener(similar = symbols, data_type = "overview").sort_values(by = ["Market Cap"], ascending = False)
mike_portfolio_overview
# Out:
#    Ticker                            Company                  Sector  \
# 0    AAPL                         Apple Inc.              Technology
# 20   MSFT              Microsoft Corporation              Technology
# 22   NVDA                 NVIDIA Corporation              Technology
# 32      V                          Visa Inc.               Financial
# 35    XOM            Exxon Mobil Corporation                  Energy
# 31    UNH    UnitedHealth Group Incorporated              Healthcare
# 14    JNJ                  Johnson & Johnson              Healthcare
# 15    JPM               JPMorgan Chase & Co.               Financial
# 34    WMT                       Walmart Inc.      Consumer Defensive
# 16     MA            Mastercard Incorporated               Financial
# 8     CVX                Chevron Corporation                  Energy
# 25     PG       The Procter & Gamble Company      Consumer Defensive
# 12     HD               The Home Depot, Inc.       Consumer Cyclical
# 4     BAC        Bank of America Corporation               Financial
# 19    MRK                  Merck & Co., Inc.              Healthcare
# 3    AVGO                      Broadcom Inc.              Technology
# 24    PFE                        Pfizer Inc.              Healthcare
# 23    PEP                      PepsiCo, Inc.      Consumer Defensive
# 7    COST       Costco Wholesale Corporation      Consumer Defensive
# 9     DIS            The Walt Disney Company  Communication Services
# 21    NKE                         NIKE, Inc.       Consumer Cyclical
# 17    MCD             McDonald's Corporation       Consumer Cyclical
# 33     VZ        Verizon Communications Inc.  Communication Services
# 1    AMGN                         Amgen Inc.              Healthcare
# 11     GS      The Goldman Sachs Group, Inc.               Financial
# 27   SBUX              Starbucks Corporation       Consumer Cyclical
# 5     BUD         Anheuser-Busch InBev SA/NV      Consumer Defensive
# 18     MO                 Altria Group, Inc.      Consumer Defensive
# 10    ETN              Eaton Corporation plc             Industrials
# 2     APD   Air Products and Chemicals, Inc.         Basic Materials
# 28    SHW       The Sherwin-Williams Company         Basic Materials
# 6     COF  Capital One Financial Corporation               Financial
# 30   TSCO             Tractor Supply Company       Consumer Cyclical
# 13    IWM           iShares Russell 2000 ETF               Financial
# 26    QQQ                  Invesco QQQ Trust               Financial
# 9   0.0000  10697883.0
# 21  0.0084   4843251.0
# 17  0.0015   2200724.0
# 33  0.0002  12290800.0
# 1  -0.0108   2007767.0
# 11 -0.0060   2148970.0
# 27 -0.0050   5106798.0
# 5  -0.0008    977749.0
# 18 -0.0092   6395666.0
# 10 -0.0077   1244763.0
# 2  -0.0182   1680819.0
# 28 -0.0048   1246221.0
# 6  -0.0172   2827933.0
# 30  0.0035    850763.0
# 13 -0.0005  21784931.0
# 26  0.0074  63853003.0
# 29 -0.0005  87278478.0

# %%
#Look at the valuation data of all the stocks in the portfolio
mike_portfolio_valuation = openbb.stocks.ca.screener(similar = symbols, data_type = "valuation")
mike_portfolio_valuation
# Out:
#    Ticker    Market Cap    P/E  Fwd P/E    PEG    P/S     P/B     P/C  \
# 0    AAPL  2.421680e+12  26.03    23.26   3.20   6.25   42.91   47.16
# 1    AMGN  1.273800e+11  19.90    12.80   3.92   4.84   35.24   13.69
# 2     APD  6.231000e+10  27.77    22.51   3.16   4.84    4.49   19.78
# 3    AVGO  2.543100e+11  22.70    13.90   2.70   7.66   10.93   20.48
# 4     BAC  2.868800e+11  11.19     9.63   3.33   3.95    1.20    0.34
# 5     BUD  1.027200e+11  23.93    17.88   2.26   1.79    9.76   13.95
# 6     COF  4.406000e+10   6.47     7.64    NaN   1.41    0.96    1.77
# 7    COST  2.235800e+11  38.03    31.63   3.66   0.97   10.40   19.15
# 8     CVX  3.263700e+11   9.44    11.07    NaN   1.38    2.10   21.15
# 9     DIS  2.008600e+11  59.22    19.67   2.87   2.38    2.04   23.71
# 10    ETN  6.733000e+10  28.17    19.14   3.17   3.24    4.29  129.97
# 11     GS  1.247800e+11  12.37     9.20    NaN   1.82    1.21    0.44
# 12     HD  3.235200e+11  19.19    18.93   4.89   2.06  250.73  131.41
# 13    IWM           NaN    NaN      NaN    NaN    NaN     NaN     NaN
# 14    JNJ  4.216900e+11  24.05    14.83   6.18   4.44    5.71   12.37
# 15    JPM  4.181900e+11  11.85    10.66    NaN   4.51    1.66    0.27
# 16     MA  3.571400e+11  36.20    25.51   1.78  16.06   56.14   44.39
# 17    MCD  1.939600e+11  31.95    22.82   4.38   8.37     NaN   68.58
# 18     MO  8.302000e+10  48.78     8.97  10.51   3.26     NaN   33.44
# 19    MRK  2.710000e+11  19.03    12.67   2.13   4.57    6.20   24.09
# 20   MSFT  2.029990e+12  30.26    25.36   2.57   9.95   11.07   20.40
# 21    NKE  1.956000e+11  35.64    31.51   5.27   3.98   12.88   18.42
# 22   NVDA  5.935700e+11  97.71    53.53   4.59  20.78   26.71   45.16
# 23    PEP  2.374600e+11  27.14    22.29   3.59   2.75   14.08   44.40
# 24    PFE  2.423900e+11   7.99    11.54    NaN   2.42    2.65    6.71
# 25     PG  3.257100e+11  24.46    21.99   4.83   4.06    7.55   47.52
# 26    QQQ           NaN    NaN      NaN    NaN    NaN     NaN     NaN
# 27   SBUX  1.229000e+11  37.47    26.47   2.08   3.73     NaN   37.12
# 28    SHW  6.037000e+10  30.03    23.33   3.31   2.73   23.01  462.64
# 29    SPY           NaN    NaN      NaN    NaN    NaN     NaN     NaN
#
# 5    58.82 -0.0008    977749.0
# 6   115.35 -0.0172   2827933.0
# 7   503.22 -0.0064   1254917.0
# 8   172.32  0.0077   7857713.0
# 9   107.66  0.0000  10697883.0
# 10  172.97 -0.0077   1244763.0
# 11  371.78 -0.0060   2148970.0
# 12  318.43 -0.0158   3335318.0
# 13  192.51 -0.0005  21784931.0
# 14  162.04 -0.0044   6305378.0
# 15  143.20  0.0044   8926173.0
# 16  369.96 -0.0023   1841064.0
# 17  266.61  0.0015   2200724.0
# 18   47.41 -0.0092   6395666.0
# 19  108.74 -0.0074   6334350.0
# 20  272.17  0.0031  36936877.0
# 21  126.20  0.0084   4843251.0
# 22  229.71  0.0543  67249235.0
# 23  175.77 -0.0113   5200840.0
# 24   43.72 -0.0061  17498456.0
# 25  139.28 -0.0056   5232388.0
# 26  306.75  0.0074  63853003.0
# 27  107.98 -0.0050   5106798.0
# 28  231.95 -0.0048   1246221.0
# 29  412.64 -0.0005  87278478.0
# 30  237.99  0.0035    850763.0
# 31  492.83 -0.0051   2072239.0
# 32  229.39  0.0022   4767058.0
# 33   40.33  0.0002  12290800.0
# 34  145.49 -0.0029   4610005.0
# 35  116.42 -0.0117  11967551.0

# %%
#Examine the performance metrics of the stocks in the portfolio
mike_portfolio_performance = openbb.stocks.ca.screener(similar = symbols, data_type = "performance").sort_values(by = ["Perf YTD"], ascending = False)
mike_portfolio_performance
# Out:
#    Ticker  Perf Week  Perf Month  Perf Quart  Perf Half  Perf Year  Perf YTD  \
# 22   NVDA     0.0360      0.3593      0.4069     0.2070    -0.0408    0.5718
# 6     COF    -0.0396      0.1215     -0.0077     0.0149    -0.2606    0.2409
# 9     DIS    -0.0356      0.0831      0.1331    -0.1336    -0.2797    0.2392
# 0    AAPL    -0.0094      0.1368      0.0234    -0.1154    -0.0916    0.1791
# 26    QQQ    -0.0101      0.0918      0.0653    -0.0790    -0.1161    0.1520
# 20   MSFT     0.0172      0.1377      0.1014    -0.0726    -0.0775    0.1349
# 13    IWM    -0.0157      0.0292      0.0300    -0.0426    -0.0440    0.1041
# 32      V    -0.0083      0.0284      0.1190     0.0599     0.0209    0.1041
# 7    COST    -0.0258      0.0370     -0.0238    -0.0779    -0.0127    0.1023
# 10    ETN     0.0516      0.0518      0.0704     0.1348     0.1481    0.1021
# 27   SBUX     0.0108      0.0070      0.1089     0.2111     0.1520    0.0885
# 11     GS    -0.0070     -0.0059     -0.0348     0.0448     0.0240    0.0827
# 29    SPY    -0.0061      0.0355      0.0355    -0.0378    -0.0632    0.0790
# 21    NKE     0.0069     -0.0206      0.1896     0.0849    -0.0997    0.0785
# 3    AVGO    -0.0198      0.0403      0.1626     0.0776     0.0504    0.0772
# 4     BAC    -0.0313      0.0111     -0.0726    -0.0174    -0.2567    0.0755
# 15    JPM    -0.0031      0.0013      0.0584     0.1694    -0.0696    0.0679
# 16     MA    -0.0136     -0.0148      0.0904     0.0278     0.0005    0.0639
# 30   TSCO     0.0226      0.0764      0.1384     0.2007     0.0845    0.0579
# 18        0.0131        0.0285    2.7   7690000.0        0.83   47.41 -0.0092
# 34        0.0118        0.0156    2.0   6240000.0        0.74  145.49 -0.0029
# 33        0.0155        0.0360    2.8  23040000.0        0.53   40.33  0.0002
# 17        0.0124        0.0166    2.0   2810000.0        0.78  266.61  0.0015
# 12        0.0211        0.0230    2.3   3840000.0        0.87  318.43 -0.0158
# 19        0.0158        0.0229    2.0   9010000.0        0.70  108.74 -0.0074
# 5         0.0105        0.0127    2.6   1240000.0        0.79   58.82 -0.0008
# 28        0.0228        0.0264    2.6   1500000.0        0.83  231.95 -0.0048
# 23        0.0163        0.0153    2.5   4790000.0        1.08  175.77 -0.0113
# 8         0.0175        0.0215    2.6   8450000.0        0.93  172.32  0.0077
# 31        0.0170        0.0223    1.8   3590000.0        0.58  492.83 -0.0051
# 25        0.0135        0.0160    2.4   6740000.0        0.78  139.28 -0.0056
# 1         0.0155        0.0193    2.7   2620000.0        0.77  241.03 -0.0108
# 14        0.0120        0.0170    2.5   7040000.0        0.90  162.04 -0.0044
# 2         0.0195        0.0211    2.4   1110000.0        1.51  281.49 -0.0182
# 24        0.0161        0.0169    2.4  22100000.0        0.79   43.72 -0.0061
#
#         Volume
# 22  67249235.0
# 6    2827933.0
# 9   10697883.0
# 0   60318993.0
# 26  63853003.0
# 20  36936877.0
# 13  21784931.0
# 32   4767058.0
# 7    1254917.0
# 10   1244763.0
# 27   5106798.0
# 11   2148970.0
# 29  87278478.0
# 21   4843251.0
# 3    1756097.0
# 4   33596821.0
# 15   8926173.0
# 16   1841064.0
# 30    850763.0
# 35  11967551.0
# 18   6395666.0
# 34   4610005.0
# 33  12290800.0
# 17   2200724.0
# 12   3335318.0
# 19   6334350.0
# 5     977749.0
# 28   1246221.0
# 23   5200840.0
# 8    7857713.0
# 31   2072239.0
# 25   5232388.0
# 1    2007767.0
# 14   6305378.0
# 2    1680819.0
# 24  17498456.0

# %%
#Plotting the YTD Performance of the stock in the portfolio
mike_portfolio_performance.plot(
    kind="bar",
    x="Ticker", 
    y=["Perf YTD"],
    figsize=(15, 10),
    title="Stocks in Mike's Portfolio Performance YTD"

)
# Out:
# <AxesSubplot: title={'left': "Stocks in Mike's Portfolio Performance YTD"}, xlabel='Ticker'>

# %%
#Look at the Balance sheet of a few of the stocks in the portfolio
openbb.stocks.ca.balance(["NVDA", "COST", "MSFT", "SBUX"], timeframe = '2022')
# Out:
# Other available yearly timeframes are: 2018, 2019, 2020, 2021, 2022
#                                         NVDA    COST     MSFT    SBUX
# Item
# Cash & Short Term Investments         21.21B  11.05B  104.76B   3.18B
# Cash & Short Term Investments Growth  83.44%       -  -19.62%       -
# Cash Only                              1.99B   10.2B   13.93B   2.82B
# Short-Term Investments                     -       -        -       -
# Cash & ST Investments / Total Assets  48.00%  17.22%   28.71%  11.38%
# Total Accounts Receivable              4.65B   2.24B   44.26B   1.27B
# Total Accounts Receivable Growth      91.44%       -   16.34%       -
# Accounts Receivables, Net              4.65B       -   44.26B       -
# Accounts Receivables, Gross            4.65B       -   44.89B       -
# Bad Debt/Doubtful Accounts                 -       -   (633M)       -
# Other Receivable                           -       -        -       -
# Accounts Receivable Turnover            5.79  101.27     4.48   25.32
# Inventories                            2.61B  17.91B    3.74B   2.18B
# Finished Goods                         1.12B       -    2.52B       -
# Work in Progress                        692M       -      82M       -
# Raw Materials                           791M       -    1.14B       -
# Progress Payments & Other                  -       -        -       -
# Other Current Assets                    366M    1.5B   16.92B  386.6M
# Miscellaneous Current Assets            366M       -   16.92B       -
# Total Current Assets                  28.83B   32.7B  169.68B   7.02B
# Net Property, Plant & Equipment        3.61B  29.04B   87.55B  14.58B
# Property, Plant & Equipment - Gross    5.51B       -  147.21B       -
# Buildings                                  -       -   55.01B       -
# Land & Improvements                     218M       -    4.73B       -
# Computer Software and Equipment        2.85B       -   60.63B       -
# Other Property, Plant & Equipment       874M       -   13.68B       -
# Accumulated Depreciation                1.9B       -   59.66B       -
# Total Investments and Advances          266M       -    6.89B  746.5M
# Other Long-Term Investments             266M       -    6.89B       -
# Long-Term Note Receivables                 -       -     3.8B       -
# Intangible Assets                      6.69B       -   78.82B   3.44B
# Net Goodwill                           4.35B       -   67.52B       -
# Net Other Intangibles                      -       -        -       -
# Other Assets                           3.58B   1.99B    4.58B    398M
# Total Assets                          44.19B  64.17B  364.84B  27.98B
# Total Assets Growth                   53.48%       -    9.31%       -

# %%
# Examine the divindends of Costco
cost_divs = openbb.stocks.fa.divs("COST")
cost_divs
# Out:
#                            Dividends  Change
# Date
# 2023-02-02 00:00:00-05:00      0.900   0.000
# 2022-10-27 00:00:00-04:00      0.900   0.000
# 2022-07-28 00:00:00-04:00      0.900   0.000
# 2022-04-28 00:00:00-04:00      0.900   0.110
# 2022-02-03 00:00:00-05:00      0.790   0.000
# ...                              ...     ...
# 2005-05-04 00:00:00-04:00      0.115   0.015
# 2005-02-04 00:00:00-05:00      0.100   0.000
# 2004-11-03 00:00:00-05:00      0.100   0.000
# 2004-07-21 00:00:00-04:00      0.100   0.000
# 2004-05-06 00:00:00-04:00      0.100     NaN
#
# [80 rows x 2 columns]

# %%
#Plot the dividends and changes in dividends of Costco overtime
cost_divs.plot(
    title="Costco Dividends & Dividend Changes by Year (Log Scale)",
    figsize = (15,10),
    logy=True


)
# Out:
# <AxesSubplot: title={'left': 'Costco Dividends & Dividend Changes by Year (Log Scale)'}, xlabel='Date'>

# %%
# News
cost_news = openbb.news(term = "Costco dividend increase")
cost_news
# Out:
# Fetching data. Please be patient

# %%
# Out:
#                                                 title  \
# 23  Earnings Previews: Cenovus Energy, Datadog, Pa...
# 18  Why the Highest Yielding Warren Buffett Stocks...
# 22  Consumers suing to block grocery merger | Nort...
# 13  Got $1000? 3 Simple Stocks to Buy Right Now - ...
# 2   Barclays Initiates Coverage of Costco Wholesal...
# ..                                                ...
# 19  Costco Just Raised Its Dividend. It's One More...
# 68  Costco Wholesale Corporation Announces an Incr...
# 84  Costco Stock: Is Another Stock Split Likely? W...
# 26  Is Costco Ready to Issue a Special Dividend? -...
# 70  Is Costco a Great Dividend Stock? - The Motley...
#
#                                                  link  \
# 23  https://news.google.com/rss/articles/CBMiZWh0d...
# 18  https://news.google.com/rss/articles/CBMieGh0d...
# 22  https://news.google.com/rss/articles/CBMieWh0d...
# 13  https://news.google.com/rss/articles/CBMiTGh0d...
# 2   https://news.google.com/rss/articles/CBMidWh0d...
# ..                                                ...
# 19  https://news.google.com/rss/articles/CBMiTmh0d...
# 68  https://news.google.com/rss/articles/CBMiXWh0d...
# 84  https://news.google.com/rss/articles/CBMiUGh0d...
# 26  https://news.google.com/rss/articles/CBMiVmh0d...
# 70  https://news.google.com/rss/articles/CBMiS2h0d...
#
#                    published
# 23 2023-02-14 16:47:05+00:00
# 18 2023-02-14 11:49:05+00:00
# 22 2023-02-14 08:00:00+00:00
# 13 2023-02-10 10:40:00+00:00
# 2  2023-02-09 04:07:00+00:00
# ..                       ...
# 19 2022-04-13 07:00:00+00:00
# 68 2022-04-13 07:00:00+00:00
# 84 2022-04-06 07:00:00+00:00
# 26 2022-03-15 07:00:00+00:00
# 70 2021-01-18 08:00:00+00:00
#
# [100 rows x 3 columns]

# %%
# Creating the Portfolio Object
port = rp.Portfolio(returns=returns)

# %%
# Calculating optimal portfolio

# Select method and estimate input parameters:

method_mu='hist' # Method to estimate expected returns based on historical data.
method_cov='hist' # Method to estimate covariance matrix based on historical data.

port.assets_stats(method_mu=method_mu, method_cov=method_cov, d=0.94)

# %%
# Estimate optimal portfolio:

model='Classic' # Could be Classic (historical), BL (Black Litterman) or FM (Factor Model)
rm = 'MV' # Risk measure used, MV is standard deviation
obj = 'Sharpe' # Objective function, could be MinRisk, MaxRet, Utility or Sharpe
hist = True # Use historical scenarios for risk measures that depend on scenarios
rf = 0 # Risk free rate
l = 0 # Risk aversion factor, only useful when obj is 'Utility'

w = port.optimization(model=model, rm=rm, obj=obj, rf=rf, l=l, hist=hist)

# To display dataframes values in percentage format --- NEED TO RESET OR ALL DF'S WILL CHG DISPLAY
pd.options.display.float_format = '{:.4%}'.format

w
# Out:
#       weights
# SPY   0.0000%
# COST 20.8710%
# AVGO 13.2707%
# APD   0.0000%
# AMGN  0.0000%
# CVX   0.0000%
# AAPL  0.6922%
# DIS   0.0000%
# BAC   0.0000%
# GS    0.0000%
# SBUX  0.0000%
# COF   0.0000%
# ETN   0.0000%
# XOM   0.0000%
# HD    0.0000%
# MA    0.0000%
# QQQ   0.0000%
# IWM   0.0000%
# JNJ   0.0000%
# JPM   0.0000%
# MCD   0.0001%
# MRK  14.0011%
# MSFT  0.0005%
# NVDA 22.0531%
# NKE   0.0000%
# PEP   0.0000%
# PFE   0.0000%
# PG    0.0000%
# MO    0.0000%
# BUD   0.0000%
# SHW   0.0000%
# TSCO  2.0959%
# UNH  27.0154%
# VZ    0.0000%
# V     0.0000%
# WMT   0.0000%

# %%
# Plotting the composition of the portfolio

ax = rp.plot_pie(w=w, title='Sharpe Mean Variance', others=0.05, nrow=25, cmap = "tab20",
                 height=6, width=10, ax=None)

# %%
points = 50 # Number of points of the frontier

frontier = port.efficient_frontier(model=model, rm=rm, points=points, rf=rf, hist=hist)

display(frontier.T.head())
#frontier
# Out:
#       SPY     COST    AVGO     APD    AMGN     CVX    AAPL     DIS     BAC  \
# 0 0.0000%  5.1221% 0.0000% 0.0000% 0.0000% 0.0000% 0.0000% 0.0000% 0.0000%
# 1 0.0000% 11.7060% 1.5965% 0.0000% 0.0000% 0.0000% 1.6029% 0.0000% 0.0000%
# 2 0.0000% 13.9286% 3.0010% 0.0000% 0.0000% 0.0000% 1.6002% 0.0000% 0.0000%
# 3 0.0000% 15.6989% 4.1184% 0.0000% 0.0000% 0.0000% 1.5962% 0.0000% 0.0000%
# 4 0.0000% 17.2526% 5.0884% 0.0000% 0.0000% 0.0000% 1.5781% 0.0000% 0.0000%
#
#        GS  ...     PFE      PG      MO     BUD     SHW    TSCO      UNH  \
# 0 0.0000%  ... 5.8643% 8.0606% 6.4966% 3.0324% 0.0000% 2.3385%  0.0000%
# 1 0.0000%  ... 2.9364% 4.3812% 7.4942% 0.0000% 0.0000% 3.7441%  4.7970%
# 2 0.0000%  ... 1.2251% 2.6930% 7.3184% 0.0000% 0.0000% 3.8454%  7.9791%
# 3 0.0000%  ... 0.0000% 1.3391% 7.1748% 0.0000% 0.0000% 3.9227% 10.5032%
# 4 0.0000%  ... 0.0000% 0.0795% 7.0200% 0.0000% 0.0000% 3.9631% 12.6367%
#
#         VZ       V      WMT
# 0 21.0123% 0.0000% 13.1311%
# 1 11.4876% 0.0000%  9.1545%
# 2  7.2880% 0.0000%  7.6333%
# 3  3.9253% 0.0000%  6.4174%
# 4  0.8375% 0.0000%  5.3172%
#
# [5 rows x 36 columns]

# %%
pd.reset_option("display.float_format")

# %%
# Plotting the efficient frontier


label = 'Max Risk Adjusted Return Portfolio' # Title of point
mu = port.mu # Expected returns
cov = port.cov # Covariance matrix
returns = port.returns # Returns of the assets

ax = rp.plot_frontier(w_frontier=frontier, mu=mu, cov=cov, returns=returns, rm=rm,
                      rf=rf, alpha=0.05, cmap='viridis', w=w, label=label,
                      marker='*', s=16, c='r', height=8, width=15, ax=None)

# %%
ax = rp.plot_hist(returns=returns, w=w, alpha=0.05, bins=50, height=8,
                  width=15, ax=None)

# %%
ax = rp.plot_clusters(returns=returns, codependence='spearman',
                      linkage='ward', k=None, max_k=10,
                      leaf_order=True, dendrogram=True, ax=None)

# %%
nav=port.nav

ax = rp.plot_drawdown(nav=nav, w=w1, alpha=0.05, height=8, width=10, ax=None)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/ys/fqvy458x0ds2sdvqh8qgff500000gn/T/ipykernel_56859/671540665.py in <module>
# ----> 1 nav=port.nav
#       2
#       3 ax = rp.plot_drawdown(nav=nav, w=w1, alpha=0.05, height=8, width=10, ax=None)
#
# AttributeError: 'Portfolio' object has no attribute 'nav'
