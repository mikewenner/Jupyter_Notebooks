# %%
from openbb_terminal.sdk import openbb
import pandas as pd
import numpy as np

# %matplotlib inline

# %%
openbb.ta.bbands_chart(data= openbb.stocks.load('QQQ', start_date = '2022-11-18'))
# Out:
# Loading Daily data for QQQ with starting period 2022-11-18.

# %%
openbb.ta.bbands(data= openbb.stocks.load('QQQ', start_date = '2022-11-18'))
# Out:
# Loading Daily data for QQQ with starting period 2022-11-18.
#             BBL_15_2.0  BBM_15_2.0  BBU_15_2.0  BBB_15_2.0  BBP_15_2.0
# date
# 2022-12-09  275.844537  284.680019  293.515501    6.207307    0.287871
# 2022-12-12  275.831047  284.652210  293.473374    6.197854    0.488966
# 2022-12-13  276.354608  285.010122  293.665637    6.073830    0.644727
# 2022-12-14  276.402929  285.056846  293.710763    6.071713    0.518897
# 2022-12-15  274.184379  283.899956  293.615533    6.844367    0.083235
# ...                ...         ...         ...         ...         ...
# 2023-03-21  287.368739  300.129323  312.889907    8.503390    0.900086
# 2023-03-22  288.129264  300.878157  313.627051    8.474456    0.705580
# 2023-03-23  288.589619  301.987137  315.384656    8.872907    0.789713
# 2023-03-24  288.678755  303.099997  317.521239    9.515831    0.770088
# 2023-03-27  288.887185  303.807499  318.727813    9.822216    0.665965
#
# [73 rows x 5 columns]
