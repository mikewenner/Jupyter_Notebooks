# %%
# Imports
import pandas as pd
from pathlib import Path
import tensorflow as tf
from tensorflow.keras.layers import Dense
from tensorflow.keras.models import Sequential
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
# Out:
# 2023-03-21 19:22:20.380107: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
# Read the credit_card_transactions.csv file from the Resources folder into a Pandas DataFrame
cc_transactions_df = pd.read_csv(
    Path("credit_card_transactions.csv")
)

# Review the DataFrame
cc_transactions_df.head()
# Out:
#    dateMonth  dateWeekday  dateQuarter  operationType     amount  \
# 0          1            1            1              4     736.76
# 1          1            1            1              2  256226.20
# 2          1            1            1              5  310027.49
# 3          1            1            1              1   76695.35
# 4          1            1            1              4    4761.57
#
#    oldbalanceOrig  newbalanceOrig  oldbalanceDest  newbalanceDest  isFraud
# 0         1120.00          383.24            0.00            0.00        0
# 1            0.00            0.00       518041.64      1305828.01        0
# 2        61594.00            0.00        10089.00      1157398.83        0
# 3      9064440.33      9141135.68       880045.33       206147.08        0
# 4            0.00            0.00            0.00            0.00        0

# %%
# we know the this is a binary problem because y (isfraud col) is either 0 or 1
cc_transactions_df["isFraud"].value_counts()
#cc_transactions_df["isFraud"].unique()
# Out:
# 0    99884
# 1      116
# Name: isFraud, dtype: int64

# %%
# Define the target set by selecting the isFraud column
y = cc_transactions_df["isFraud"]

# Display a sample of y
y[:5]
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name: isFraud, dtype: int64

# %%
# Define features set X by selecting all columns but the isFraud
X = cc_transactions_df.drop(columns=["isFraud"])

# Display the features DataFrame
X
# Out:
#        dateMonth  dateWeekday  dateQuarter  operationType      amount  \
# 0              1            1            1              4      736.76
# 1              1            1            1              2   256226.20
# 2              1            1            1              5   310027.49
# 3              1            1            1              1    76695.35
# 4              1            1            1              4     4761.57
# ...          ...          ...          ...            ...         ...
# 99995         12            1            4              1   109534.19
# 99996         12            1            4              1   103920.74
# 99997         12            1            4              5  1298677.95
# 99998         12            1            4              1    82450.63
# 99999         12            1            4              1    78848.28
#
#        oldbalanceOrig  newbalanceOrig  oldbalanceDest  newbalanceDest
# 0             1120.00          383.24            0.00            0.00
# 1                0.00            0.00       518041.64      1305828.01
# 2            61594.00            0.00        10089.00      1157398.83
# 3          9064440.33      9141135.68       880045.33       206147.08
# 4                0.00            0.00            0.00            0.00
# ...               ...             ...             ...             ...
# 99995     18292168.76     18401702.96       403737.01       294202.82
# 99996      5486901.65      5590822.39      1267095.24      2239899.53
# 99997            0.00            0.00       280579.46      1579257.41
# 99998      4135263.42      4217714.05      2289239.02      2436585.65
# 99999       144962.00       223810.28        13861.87            0.00
#
# [100000 rows x 9 columns]

# %%
# Create training and testing datasets using train_teat_split
# Assign the function a random_state equal to 1
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1)

# %%
# Create the StandardScaler instance
X_scaler = StandardScaler()

# %%
# Fit the scaler to the features training dataset
X_scaler.fit(X_train)
# Out:
# StandardScaler()

# %%
# Scale both the training and testing data from the features dataset
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
# Create and Evaluate a Deep Neural Network Model
# Step 1: Create a deep neural network model with the following structure:
# * 9 inputs
# * First hidden layer with 18 neurons
# * Second hidden layer with 8 neurons
# * Output layer with a single output
# * Hidden layers use the ReLU activation function, and output layer uses the sigmoid activation function

# %%
# Define the the number of inputs to the model
number_inputs = 9

# Define the number of hidden nodes for the first hidden layer
hidden_nodes_layer1 = 18

# Define the number of hidden nodes for the second hidden layer
hidden_nodes_layer2 = 8

# Create the Sequential model instance
nn = Sequential()

# Add the first Dense layer specifying the number of inputs, the number of hidden nodes, and the activation function
nn.add(Dense(units=18, input_dim=9, activation="relu"))
#units - number of hidden nodes in layer 1
#input dim is the number of inputs or number of columns is X df

# Add the second Dense layer specifying the number of hidden nodes and the activation function
nn.add(Dense(units=8, activation="relu"))
#units - number of hidden nodes in layer 2

# Add the output layer to the model specifying the number of output neurons and activation function
nn.add(Dense(units=1, activation="sigmoid"))
#units is number of output units
#here we use sigmoid because its a 0 and 1 problem and we want prob between the two numbers

# %%
# Display the Sequential model summary
nn.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_3 (Dense)             (None, 18)                180
#
#  dense_4 (Dense)             (None, 8)                 152
#
#  dense_5 (Dense)             (None, 1)                 9
#
# =================================================================
# Total params: 341
# Trainable params: 341
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the Sequential model
nn.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])
#since its a 0 and 1 classification problem, we will look at loss as binary_crossentropy and the metric we want is accuracy

# %%
# Fit the model using 100 epochs and the training data
model = nn.fit(X_train_scaled, y_train, epochs=100)
# Out:
# Epoch 1/100
# 2344/2344 [==============================] - 3s 843us/step - loss: 0.0279 - accuracy: 0.9975
# Epoch 2/100
# 2344/2344 [==============================] - 2s 829us/step - loss: 0.0089 - accuracy: 0.9989
# Epoch 3/100
# 2344/2344 [==============================] - 2s 826us/step - loss: 0.0085 - accuracy: 0.9989
# Epoch 4/100
# 2344/2344 [==============================] - 2s 850us/step - loss: 0.0082 - accuracy: 0.9989
# Epoch 5/100
# 2344/2344 [==============================] - 2s 886us/step - loss: 0.0080 - accuracy: 0.9989
# Epoch 6/100
# 2344/2344 [==============================] - 2s 846us/step - loss: 0.0078 - accuracy: 0.9989
# Epoch 7/100
# 2344/2344 [==============================] - 2s 966us/step - loss: 0.0077 - accuracy: 0.9989
# Epoch 8/100
# 2344/2344 [==============================] - 2s 835us/step - loss: 0.0076 - accuracy: 0.9989
# Epoch 9/100
# 2344/2344 [==============================] - 2s 898us/step - loss: 0.0074 - accuracy: 0.9989
# Epoch 10/100
# 2344/2344 [==============================] - 2s 910us/step - loss: 0.0074 - accuracy: 0.9989
# Epoch 11/100
# 2344/2344 [==============================] - 2s 822us/step - loss: 0.0073 - accuracy: 0.9989
# Epoch 12/100
# 2344/2344 [==============================] - 2s 844us/step - loss: 0.0073 - accuracy: 0.9989
# Epoch 13/100
# 2344/2344 [==============================] - 2s 836us/step - loss: 0.0072 - accuracy: 0.9989
# Epoch 14/100
# 2344/2344 [==============================] - 2s 811us/step - loss: 0.0070 - accuracy: 0.9989
# Epoch 15/100
# 2344/2344 [==============================] - 2s 806us/step - loss: 0.0069 - accuracy: 0.9989
# Epoch 16/100
# 2344/2344 [==============================] - 2s 808us/step - loss: 0.0067 - accuracy: 0.9989
# Epoch 17/100
# 2344/2344 [==============================] - 2s 821us/step - loss: 0.0065 - accuracy: 0.9990
# Epoch 18/100
# 2344/2344 [==============================] - 2s 802us/step - loss: 0.0064 - accuracy: 0.9989
# Epoch 19/100
# 2344/2344 [==============================] - 2s 810us/step - loss: 0.0063 - accuracy: 0.9990
# Epoch 20/100
# 2344/2344 [==============================] - 2s 802us/step - loss: 0.0061 - accuracy: 0.9990
# Epoch 21/100
# 2344/2344 [==============================] - 2s 812us/step - loss: 0.0059 - accuracy: 0.9990
# Epoch 22/100
# 2344/2344 [==============================] - 2s 790us/step - loss: 0.0059 - accuracy: 0.9990
# Epoch 23/100
# 2344/2344 [==============================] - 2s 796us/step - loss: 0.0057 - accuracy: 0.9990
# Epoch 24/100
# 2344/2344 [==============================] - 2s 792us/step - loss: 0.0057 - accuracy: 0.9990
# Epoch 25/100
# 2344/2344 [==============================] - 2s 816us/step - loss: 0.0055 - accuracy: 0.9990
# Epoch 26/100
# 2344/2344 [==============================] - 2s 793us/step - loss: 0.0055 - accuracy: 0.9990
# Epoch 27/100
# 2344/2344 [==============================] - 2s 788us/step - loss: 0.0055 - accuracy: 0.9990
# Epoch 28/100
# 2344/2344 [==============================] - 2s 822us/step - loss: 0.0054 - accuracy: 0.9990
# Epoch 29/100
# 2344/2344 [==============================] - 2s 798us/step - loss: 0.0053 - accuracy: 0.9990
# Epoch 30/100
# 2344/2344 [==============================] - 2s 788us/step - loss: 0.0053 - accuracy: 0.9990
# Epoch 31/100
# 2344/2344 [==============================] - 2s 793us/step - loss: 0.0053 - accuracy: 0.9990
# Epoch 32/100
# 2344/2344 [==============================] - 2s 823us/step - loss: 0.0052 - accuracy: 0.9990
# Epoch 33/100
# 2344/2344 [==============================] - 2s 815us/step - loss: 0.0052 - accuracy: 0.9990
# Epoch 34/100
# 2344/2344 [==============================] - 2s 846us/step - loss: 0.0052 - accuracy: 0.9990
# Epoch 35/100
# 2344/2344 [==============================] - 2s 917us/step - loss: 0.0051 - accuracy: 0.9990
# Epoch 36/100
# 2344/2344 [==============================] - 2s 962us/step - loss: 0.0052 - accuracy: 0.9990
# Epoch 37/100
# 2344/2344 [==============================] - 2s 1ms/step - loss: 0.0051 - accuracy: 0.9990
# Epoch 38/100
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.0051 - accuracy: 0.9990
# Epoch 39/100
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.0050 - accuracy: 0.9990
# Epoch 40/100
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.0049 - accuracy: 0.9990
# Epoch 41/100
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.0050 - accuracy: 0.9990
# Epoch 42/100
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.0049 - accuracy: 0.9990
# Epoch 43/100
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.0051 - accuracy: 0.9990
# Epoch 44/100
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.0049 - accuracy: 0.9990
# Epoch 45/100
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.0049 - accuracy: 0.9990
# Epoch 46/100
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.0050 - accuracy: 0.9990
# Epoch 47/100
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.0050 - accuracy: 0.9990
# Epoch 48/100
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.0049 - accuracy: 0.9990
# Epoch 49/100
# 2344/2344 [==============================] - 2s 1ms/step - loss: 0.0049 - accuracy: 0.9990
# Epoch 50/100
# 2344/2344 [==============================] - 2s 1ms/step - loss: 0.0049 - accuracy: 0.9990
# Epoch 51/100
# 2344/2344 [==============================] - 2s 1ms/step - loss: 0.0048 - accuracy: 0.9990
# Epoch 52/100
# 2344/2344 [==============================] - 2s 955us/step - loss: 0.0049 - accuracy: 0.9990
# Epoch 53/100
# 2344/2344 [==============================] - 2s 1ms/step - loss: 0.0046 - accuracy: 0.9990
# Epoch 54/100
# 2344/2344 [==============================] - 2s 973us/step - loss: 0.0048 - accuracy: 0.9990
# Epoch 55/100
# 2344/2344 [==============================] - 2s 1ms/step - loss: 0.0048 - accuracy: 0.9990
# Epoch 56/100
# 2344/2344 [==============================] - 2s 1ms/step - loss: 0.0047 - accuracy: 0.9990
# Epoch 57/100
# 2344/2344 [==============================] - 2s 987us/step - loss: 0.0047 - accuracy: 0.9990
# Epoch 58/100
# 2344/2344 [==============================] - 2s 968us/step - loss: 0.0048 - accuracy: 0.9990
# Epoch 59/100
# 2344/2344 [==============================] - 2s 995us/step - loss: 0.0048 - accuracy: 0.9990
# Epoch 60/100
# 2344/2344 [==============================] - 2s 997us/step - loss: 0.0047 - accuracy: 0.9990
# Epoch 61/100
# 2344/2344 [==============================] - 2s 979us/step - loss: 0.0047 - accuracy: 0.9990
# Epoch 62/100
# 2344/2344 [==============================] - 2s 967us/step - loss: 0.0047 - accuracy: 0.9990
# Epoch 63/100
# 2344/2344 [==============================] - 2s 970us/step - loss: 0.0048 - accuracy: 0.9990
# Epoch 64/100
# 2344/2344 [==============================] - 2s 1ms/step - loss: 0.0046 - accuracy: 0.9990
# Epoch 65/100
# 2344/2344 [==============================] - 2s 988us/step - loss: 0.0045 - accuracy: 0.9990
# Epoch 66/100
# 2344/2344 [==============================] - 2s 990us/step - loss: 0.0048 - accuracy: 0.9990
# Epoch 67/100
# 2344/2344 [==============================] - 2s 998us/step - loss: 0.0047 - accuracy: 0.9990
# Epoch 68/100
# 2344/2344 [==============================] - 2s 996us/step - loss: 0.0046 - accuracy: 0.9990
# Epoch 69/100
# 2344/2344 [==============================] - 2s 1ms/step - loss: 0.0047 - accuracy: 0.9990
# Epoch 70/100
# 2344/2344 [==============================] - 2s 1ms/step - loss: 0.0047 - accuracy: 0.9990
# Epoch 71/100
# 2344/2344 [==============================] - 2s 998us/step - loss: 0.0046 - accuracy: 0.9990
# Epoch 72/100
# 2344/2344 [==============================] - 2s 941us/step - loss: 0.0045 - accuracy: 0.9990
# Epoch 73/100
# 2344/2344 [==============================] - 2s 955us/step - loss: 0.0046 - accuracy: 0.9990
# Epoch 74/100
# 2344/2344 [==============================] - 2s 943us/step - loss: 0.0046 - accuracy: 0.9990
# Epoch 75/100
# 2344/2344 [==============================] - 2s 954us/step - loss: 0.0046 - accuracy: 0.9990
# Epoch 76/100
# 2344/2344 [==============================] - 2s 966us/step - loss: 0.0046 - accuracy: 0.9990
# Epoch 77/100
# 2344/2344 [==============================] - 2s 932us/step - loss: 0.0046 - accuracy: 0.9990
# Epoch 78/100
# 2344/2344 [==============================] - 2s 931us/step - loss: 0.0046 - accuracy: 0.9990
# Epoch 79/100
# 2344/2344 [==============================] - 2s 949us/step - loss: 0.0046 - accuracy: 0.9991
# Epoch 80/100
# 2344/2344 [==============================] - 2s 910us/step - loss: 0.0045 - accuracy: 0.9991
# Epoch 81/100
# 2344/2344 [==============================] - 2s 924us/step - loss: 0.0045 - accuracy: 0.9990
# Epoch 82/100
# 2344/2344 [==============================] - 2s 917us/step - loss: 0.0046 - accuracy: 0.9990
# Epoch 83/100
# 2344/2344 [==============================] - 2s 932us/step - loss: 0.0045 - accuracy: 0.9990
# Epoch 84/100
# 2344/2344 [==============================] - 2s 913us/step - loss: 0.0045 - accuracy: 0.9990
# Epoch 85/100
# 2344/2344 [==============================] - 2s 925us/step - loss: 0.0045 - accuracy: 0.9990
# Epoch 86/100
# 2344/2344 [==============================] - 2s 913us/step - loss: 0.0046 - accuracy: 0.9990
# Epoch 87/100
# 2344/2344 [==============================] - 2s 930us/step - loss: 0.0045 - accuracy: 0.9990
# Epoch 88/100
# 2344/2344 [==============================] - 2s 921us/step - loss: 0.0047 - accuracy: 0.9990
# Epoch 89/100
# 2344/2344 [==============================] - 2s 927us/step - loss: 0.0046 - accuracy: 0.9990
# Epoch 90/100
# 2344/2344 [==============================] - 2s 925us/step - loss: 0.0045 - accuracy: 0.9990
# Epoch 91/100
# 2344/2344 [==============================] - 2s 923us/step - loss: 0.0045 - accuracy: 0.9990
# Epoch 92/100
# 2344/2344 [==============================] - 2s 926us/step - loss: 0.0045 - accuracy: 0.9990
# Epoch 93/100
# 2344/2344 [==============================] - 2s 919us/step - loss: 0.0045 - accuracy: 0.9990
# Epoch 94/100
# 2344/2344 [==============================] - 2s 932us/step - loss: 0.0045 - accuracy: 0.9990
# Epoch 95/100
# 2344/2344 [==============================] - 2s 974us/step - loss: 0.0045 - accuracy: 0.9990
# Epoch 96/100
# 2344/2344 [==============================] - 2s 917us/step - loss: 0.0046 - accuracy: 0.9990
# Epoch 97/100
# 2344/2344 [==============================] - 2s 941us/step - loss: 0.0045 - accuracy: 0.9990
# Epoch 98/100
# 2344/2344 [==============================] - 2s 946us/step - loss: 0.0045 - accuracy: 0.9990
# Epoch 99/100
# 2344/2344 [==============================] - 2s 951us/step - loss: 0.0045 - accuracy: 0.9990
# Epoch 100/100
# 2344/2344 [==============================] - 2s 961us/step - loss: 0.0046 - accuracy: 0.9990

# %%
# Evaluate the model loss and accuracy metrics using the evaluate method and the test data
model_loss, model_accuracy = nn.evaluate(X_test_scaled, y_test, verbose=2)

# Display the evaluation results
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 782/782 - 1s - loss: 0.0056 - accuracy: 0.9989 - 599ms/epoch - 766us/step
# Loss: 0.005637311842292547, Accuracy: 0.9988800287246704
