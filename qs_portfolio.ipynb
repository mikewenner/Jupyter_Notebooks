# %%
#from openbb_terminal.sdk import openbb
import quantstats as qs
import pandas as pd
qs.extend_pandas()

# %%
# to make your own index / weighted portfolio
# qs.utils.make_index -- has a ticker_weights varialbe that is a dictionary of tickers and weights

tickers = {
    "AAPL": 0.25,
    "AMZN": 0.25,
    "MSFT": 0.25,
    "GOOG": 0.25
}

portfolio = qs.utils.make_index(tickers, period="10Y")
portfolio.tail()
# Out:
# /Users/mikewenner/opt/anaconda3/envs/dev/lib/python3.9/site-packages/quantstats/utils.py:394: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   return index[index.index <= last_day].sum(axis=1)
# Date
# 2023-01-13 00:00:00-05:00    0.052736
# 2023-01-17 00:00:00-05:00   -0.014555
# 2023-01-18 00:00:00-05:00   -0.034525
# 2023-01-19 00:00:00-05:00   -0.011449
# 2023-01-20 00:00:00-05:00    0.150255
# dtype: float64

# %%
portfolio.plot(title = "Daily returns - 10Yr - basket equal weight portfolio example")
# Out:
# <AxesSubplot: title={'center': 'Daily returns - 10Yr - basket equal weight portfolio example'}, xlabel='Date'>

# %%
#data_spy = openbb.stocks.load("SPY", start_date="2013-01-23", end_date="2023-01-19")
data_spy = qs.utils.download_returns("SPY", period="10Y")
data_spy.head()
# Out:
# Date
# 2013-01-22 00:00:00-05:00         NaN
# 2013-01-23 00:00:00-05:00    0.001609
# 2013-01-24 00:00:00-05:00    0.000268
# 2013-01-25 00:00:00-05:00    0.005622
# 2013-01-28 00:00:00-05:00   -0.001198
# Name: Close, dtype: float64

# %%
qs.reports.metrics(portfolio, mode="full")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/opt/anaconda3/envs/dev/lib/python3.9/site-packages/pandas/core/arrays/datetimelike.py in _validate_comparison_value(self, other)
#     581             try:
# --> 582                 self._check_compatible_with(other)
#     583             except (TypeError, IncompatibleFrequency) as err:
#
# ~/opt/anaconda3/envs/dev/lib/python3.9/site-packages/pandas/core/arrays/datetimes.py in _check_compatible_with(self, other, setitem)
#     460             return
# --> 461         self._assert_tzawareness_compat(other)
#     462         if setitem:
#
# ~/opt/anaconda3/envs/dev/lib/python3.9/site-packages/pandas/core/arrays/datetimes.py in _assert_tzawareness_compat(self, other)
#     697         elif other_tz is None:
# --> 698             raise TypeError(
# ...
