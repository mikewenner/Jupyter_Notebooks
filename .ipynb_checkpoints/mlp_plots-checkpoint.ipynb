# %%
import yfinance as yf
import mplfinance as mpf
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /var/folders/ys/fqvy458x0ds2sdvqh8qgff500000gn/T/ipykernel_23225/2272132026.py in <module>
#       1 import yfinance as yf
# ----> 2 import mplfinance as mpf
#
# ModuleNotFoundError: No module named 'mplfinance'

# %%
# %pip install yfinance
# %pip install mplfinance
# Out:
# Requirement already satisfied: yfinance in /Users/mikewenner/opt/anaconda3/envs/dev/lib/python3.7/site-packages (0.2.4)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in /Users/mikewenner/opt/anaconda3/envs/dev/lib/python3.7/site-packages (from yfinance) (4.11.1)
# Requirement already satisfied: lxml>=4.9.1 in /Users/mikewenner/opt/anaconda3/envs/dev/lib/python3.7/site-packages (from yfinance) (4.9.1)
# Requirement already satisfied: multitasking>=0.0.7 in /Users/mikewenner/opt/anaconda3/envs/dev/lib/python3.7/site-packages (from yfinance) (0.0.11)
# Requirement already satisfied: cryptography>=3.3.2 in /Users/mikewenner/opt/anaconda3/envs/dev/lib/python3.7/site-packages (from yfinance) (37.0.1)
# Requirement already satisfied: numpy>=1.16.5 in /Users/mikewenner/opt/anaconda3/envs/dev/lib/python3.7/site-packages (from yfinance) (1.21.5)
# Requirement already satisfied: requests>=2.26 in /Users/mikewenner/opt/anaconda3/envs/dev/lib/python3.7/site-packages (from yfinance) (2.28.1)
# Requirement already satisfied: frozendict>=2.3.4 in /Users/mikewenner/opt/anaconda3/envs/dev/lib/python3.7/site-packages (from yfinance) (2.3.4)
# Requirement already satisfied: pytz>=2022.5 in /Users/mikewenner/opt/anaconda3/envs/dev/lib/python3.7/site-packages (from yfinance) (2022.7.1)
# Requirement already satisfied: html5lib>=1.1 in /Users/mikewenner/opt/anaconda3/envs/dev/lib/python3.7/site-packages (from yfinance) (1.1)
# Requirement already satisfied: pandas>=1.3.0 in /Users/mikewenner/opt/anaconda3/envs/dev/lib/python3.7/site-packages (from yfinance) (1.3.5)
# Requirement already satisfied: appdirs>=1.4.4 in /Users/mikewenner/opt/anaconda3/envs/dev/lib/python3.7/site-packages (from yfinance) (1.4.4)
# Requirement already satisfied: soupsieve>1.2 in /Users/mikewenner/opt/anaconda3/envs/dev/lib/python3.7/site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.3.1)
# Requirement already satisfied: cffi>=1.12 in /Users/mikewenner/opt/anaconda3/envs/dev/lib/python3.7/site-packages (from cryptography>=3.3.2->yfinance) (1.15.1)
# Requirement already satisfied: six>=1.9 in /Users/mikewenner/opt/anaconda3/envs/dev/lib/python3.7/site-packages (from html5lib>=1.1->yfinance) (1.16.0)
# Requirement already satisfied: webencodings in /Users/mikewenner/opt/anaconda3/envs/dev/lib/python3.7/site-packages (from html5lib>=1.1->yfinance) (0.5.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /Users/mikewenner/opt/anaconda3/envs/dev/lib/python3.7/site-packages (from pandas>=1.3.0->yfinance) (2.8.2)
# Requirement already satisfied: charset-normalizer<3,>=2 in /Users/mikewenner/opt/anaconda3/envs/dev/lib/python3.7/site-packages (from requests>=2.26->yfinance) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/mikewenner/opt/anaconda3/envs/dev/lib/python3.7/site-packages (from requests>=2.26->yfinance) (2022.9.24)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/mikewenner/opt/anaconda3/envs/dev/lib/python3.7/site-packages (from requests>=2.26->yfinance) (1.26.11)
# Requirement already satisfied: idna<4,>=2.5 in /Users/mikewenner/opt/anaconda3/envs/dev/lib/python3.7/site-packages (from requests>=2.26->yfinance) (3.3)
# Requirement already satisfied: pycparser in /Users/mikewenner/opt/anaconda3/envs/dev/lib/python3.7/site-packages (from cffi>=1.12->cryptography>=3.3.2->yfinance) (2.21)
# Note: you may need to restart the kernel to use updated packages.
# Collecting mplfinance
#   Downloading mplfinance-0.12.9b7-py3-none-any.whl (73 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.1/73.1 kB 1.2 MB/s eta 0:00:0000:01
# Requirement already satisfied: pandas in /Users/mikewenner/opt/anaconda3/envs/dev/lib/python3.7/site-packages (from mplfinance) (1.3.5)
# Requirement already satisfied: matplotlib in /Users/mikewenner/opt/anaconda3/envs/dev/lib/python3.7/site-packages (from mplfinance) (3.5.2)
# Requirement already satisfied: cycler>=0.10 in /Users/mikewenner/opt/anaconda3/envs/dev/lib/python3.7/site-packages (from matplotlib->mplfinance) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/mikewenner/opt/anaconda3/envs/dev/lib/python3.7/site-packages (from matplotlib->mplfinance) (1.4.2)
# Requirement already satisfied: pyparsing>=2.2.1 in /Users/mikewenner/opt/anaconda3/envs/dev/lib/python3.7/site-packages (from matplotlib->mplfinance) (3.0.9)
# Requirement already satisfied: numpy>=1.17 in /Users/mikewenner/opt/anaconda3/envs/dev/lib/python3.7/site-packages (from matplotlib->mplfinance) (1.21.5)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/mikewenner/opt/anaconda3/envs/dev/lib/python3.7/site-packages (from matplotlib->mplfinance) (2.8.2)
# Requirement already satisfied: packaging>=20.0 in /Users/mikewenner/opt/anaconda3/envs/dev/lib/python3.7/site-packages (from matplotlib->mplfinance) (21.3)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/mikewenner/opt/anaconda3/envs/dev/lib/python3.7/site-packages (from matplotlib->mplfinance) (4.25.0)
# Requirement already satisfied: pillow>=6.2.0 in /Users/mikewenner/opt/anaconda3/envs/dev/lib/python3.7/site-packages (from matplotlib->mplfinance) (9.2.0)
# Requirement already satisfied: pytz>=2017.3 in /Users/mikewenner/opt/anaconda3/envs/dev/lib/python3.7/site-packages (from pandas->mplfinance) (2022.7.1)
# Requirement already satisfied: typing-extensions in /Users/mikewenner/opt/anaconda3/envs/dev/lib/python3.7/site-packages (from kiwisolver>=1.0.1->matplotlib->mplfinance) (4.3.0)
# Requirement already satisfied: six>=1.5 in /Users/mikewenner/opt/anaconda3/envs/dev/lib/python3.7/site-packages (from python-dateutil>=2.7->matplotlib->mplfinance) (1.16.0)
# Installing collected packages: mplfinance
# Successfully installed mplfinance-0.12.9b7
# Note: you may need to restart the kernel to use updated packages.

# %%
import yfinance as yf
import mplfinance as mpf

# %%
data = yf.download("AAPL", start="2022-01-01", end="2022-06-30")
mpf.plot(data)
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
mpf.plot(data, type="candle", mav=(7, 14, 21), volume=True)
